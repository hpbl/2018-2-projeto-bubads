# %% [markdown]
#  # Analysis
#
# On this notebook we'll provide implementations to the selected analysis from the [Research Guide](Research%20Guide.ipynb) notebook.

# %%
from bs4 import BeautifulSoup
import re
import os
import pandas as pd

import matplotlib.pyplot as plt

from wordcloud import WordCloud

import holoviews as hv
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
from IPython.display import SVG, display

output_notebook()
hv.extension('bokeh')
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="35f47d70-fcbf-4fa5-a772-e5fb3472f5d1">Loading BokehJS ...</span>
#     </div>
# <link rel="stylesheet" href="https://code.jquery.com/ui/1.10.4/themes/smoothness/jquery-ui.css">
# <style>div.bk-hbox {
#     display: flex;
#     justify-content: center;
# }
#
# div.bk-hbox div.bk-plot {
#     padding: 8px;
# }
#
# div.bk-hbox div.bk-data-table {
#     padding: 20px;
# }
#
# div.hololayout {
#   display: flex;
#   align-items: center;
#   margin: 0;
# }
#
# div.holoframe {
#   width: 75%;
# }
#
# div.holowell {
#   display: flex;
#   align-items: center;
# }
#
# form.holoform {
#   background-color: #fafafa;
#   border-radius: 5px;
#   overflow: hidden;
#   padding-left: 0.8em;
#   padding-right: 0.8em;
#   padding-top: 0.4em;
#   padding-bottom: 0.4em;
#   box-shadow: inset 0 1px 1px rgba(0, 0, 0, 0.05);
#   margin-bottom: 20px;
# ...

# %%
def getFilesNames(directoryPath, extension):
    return [directoryPath + f for f in os.listdir(directoryPath) if not f.startswith('.') and f.endswith(extension)]

basePath = 'data/READMES/'
markdownFiles = getFilesNames(basePath, '.md')
htmlFiles = getFilesNames(basePath + 'HTML/', '.html')

def parsePage(htmlFilePath):
    return BeautifulSoup(open(htmlFilePath, encoding = 'utf-8').read(), "html.parser")

def parseAllPages(directoryPath):
    return list(map(parsePage, htmlFiles))

parsedPages = list(map(parsePage, htmlFiles))

# %%
def find(stringRegex, soupList, tag=None):
    findings = map(lambda x: x.find(tag, text=stringRegex), soupList)
    return list(filter(None, findings))

# %%
def showSVG(url):
    display(SVG(url=url))

# %% [markdown]
# ## README file structure
#
# ### 27. What are the most common section titles? ✅

# %%
headersRegex = re.compile('^h[1-6]$')
getHeaders = lambda parsedPage: parsedPage.find_all(headersRegex)
flatten = lambda l: [item.text for sublist in l for item in sublist]

headers = flatten(map(getHeaders, parsedPages))

# %%
# %%opts Bars [width=900, height=500, tools=['hover'] invert_axes=True] (color='#23305E')
#
# headersValueCounts = pd.DataFrame(headers)[0].value_counts()
# headersValueCountsFiltered = headersValueCounts[headersValueCounts > 5]
# headersValueCountsFiltered = headersValueCountsFiltered.rename_axis('Header').to_frame('Occurence')
#
# bar = hv.Bars(headersValueCountsFiltered)
# bar
# Out:
# :Bars   [Header]   (Occurence)

# %%
headerFrequencyDict = headersValueCounts.to_dict()

wordcloud = WordCloud(width=900, height=600, min_font_size=10,  background_color="white").generate_from_frequencies(headerFrequencyDict)
plt.figure(figsize=(9, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %% [markdown]
# ### 41. Size of the README files. ✅

# %% [markdown]
# #### Number of lines

# %%
getNameFromPath = lambda x: re.search('[^\/]+(?=$)', x).group(0)

def numberLines(filePath):
    return {getNameFromPath(filePath): len(open(filePath, encoding = 'utf-8').readlines())}

# %%
markdownNumberLines = {}
for linesDict in list(map(numberLines, markdownFiles)):
    markdownNumberLines[list(linesDict.keys())[0]] = list(linesDict.values())[0]

linesDF = pd.DataFrame.from_dict(markdownNumberLines, orient='index', columns=['numberLines'])
linesDF.describe()
# Out:
#        numberLines
# count    85.000000
# mean    219.741176
# std     171.922404
# min      38.000000
# 25%     122.000000
# 50%     178.000000
# 75%     249.000000
# max    1309.000000

# %%
maxLines = {
    'file': linesDF.idxmax()['numberLines'],
    'numLines': linesDF.max()[0]        
}

minLines = {
    'file': linesDF.idxmin()['numberLines'],
    'numLines': linesDF.min()[0]        
}

pd.DataFrame([maxLines, minLines], index=['Largest', 'Smallest'])
# Out:
#                    file  numLines
# Largest       Eureka.md      1309
# Smallest  ClassicKit.md        38

# %%
import matplotlib
% matplotlib inline
matplotlib.style.use('ggplot')

linesDF.plot.hist(bins=30, edgecolor='black', linewidth=1.2)

# %% [markdown]
# #### Number of sections

# %%
h1s = list(map(lambda x: x.find_all('h1'), parsedPages))
h2s = list(map(lambda x: x.find_all('h2'), parsedPages))
h3s = list(map(lambda x: x.find_all('h3'), parsedPages))
h4s = list(map(lambda x: x.find_all('h4'), parsedPages))
h5s = list(map(lambda x: x.find_all('h5'), parsedPages))
h6s = list(map(lambda x: x.find_all('h6'), parsedPages))

headersDF = pd.DataFrame({'h1': h1s, 'h2': h2s, 'h3': h3s, 'h4': h4s, 'h5': h5s, 'h6': h6s})

headersCountDF = headersDF.apply(lambda x: x.apply(len), result_type='broadcast')
headersMeanPlot = headersCountDF.mean().plot.bar()

headersMeanPlot.set_ylabel("Mean")
for tick in headersMeanPlot.get_xticklabels():
    tick.set_rotation(0)

# %% [markdown]
# ### - Does the order of the sections follow a common order? ❌

# %% [markdown]
# ## Package management ✅
#
# 28. What are the most adopted package management tools (Cocoapods, Catharge, Swift Package Manager, direct installation?)

# %%
cocoaRegex = re.compile(r"cocoapods", re.IGNORECASE)
cocoaList = find(cocoaRegex, parsedPages)

carthageRegex = re.compile(r"carthage", re.IGNORECASE)
carthageList = find(carthageRegex, parsedPages)

spmRegex = re.compile(r"Swift Package Manager|spm", re.IGNORECASE)
spmList = find(spmRegex, parsedPages)

# %%
packageManagersDF = pd.DataFrame([{'CocoaPods': len(cocoaList), 'Carthage': len(carthageList), 'SPM': len(spmList)}])
packageManagersDF = packageManagersDF / len(parsedPages) * 100

packageManagersPlot = packageManagersDF.plot.bar(edgecolor='black', linewidth=1.2)

packageManagersPlot.set_ylabel("Percentage")
# Out:
# Text(0, 0.5, 'Percentage')

# %% [markdown]
# ## Contributing:
# ### 10. Is there a contribution guide? ✅

# %%
contributingRegex = re.compile(r"contributing|contribution|contribute", re.IGNORECASE)
contributingList = find(contributingRegex, parsedPages)

contributingSectionList = find(contributingRegex, parsedPages, headersRegex)

# %%
fig, axes = plt.subplots(ncols=2)

labels = 'Mentions Contributing', 'Doesn\'t Mention'
contributingSize = len(contributingList) / len(parsedPages) * 100
sizes = [contributingSize, 100 - contributingSize]
colors = ['yellowgreen', 'lightcoral']
explode = (0, 0)  # explode a slice if required

axes[0].pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%')
axes[0].axis('equal')

centreCircle1 = plt.Circle((0,0), 0.75, color='white', fc='white', linewidth=1.25)
axes[0].add_patch(centreCircle1)


contributingSectionsizes = len(contributingSectionList) / len(parsedPages) * 100
sizes = [contributingSectionsizes, 100 - contributingSectionsizes]
labels = ['Has Contributing Section', 'Only Mentions']
colors = ['lightblue', 'yellowgreen']
axes[1].pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%')
axes[1].axis('equal')

centreCircle2 = plt.Circle((0,0), 0.75, color='white', fc='white', linewidth=1.25)
axes[1].add_patch(centreCircle2)


plt.show()

# %% [markdown]
# ## License/Ownership
# ### 11.What license does it use? ✅
#
# [Popular open-source licenses list](https://opensource.org/licenses)

# %%
mitRegex = re.compile(r"MIT\b")
mitList = find(mitRegex, parsedPages)
print('MIT: ' + str(len(mitList)))

apacheRegex = re.compile(r'Apache 2\.0|Apache License \(v2\)|Apache License, Version 2\.0', re.IGNORECASE)
apacheList = find(apacheRegex, parsedPages)
print('Apache 2.0: ' + str(len(apacheList)))

bsdRegex = re.compile(r'BSD\b', re.IGNORECASE)
bsdList = find(bsdRegex, parsedPages)
print('BSD: ' + str(len(bsdList)))

caRegex = re.compile(r'Creative Commons', re.IGNORECASE)
caList = find(caRegex, parsedPages)
print('Creative Commmons: ' + str(len(caList)))

licenseRegex = re.compile(r'License', re.IGNORECASE)
licenseMentions = len(find(licenseRegex, parsedPages))
print('Total Mentions: ' + str(licenseMentions))

licenses = {'MIT': mitList, 'Apache 2.0': apacheList, 'BSD': bsdList, 'Creative Commmons': caList}
# Out:
# MIT: 57
# Apache 2.0: 3
# BSD: 1
# Creative Commmons: 1
# Total Mentions: 67

# %%
fig, ax = plt.subplots(ncols=1)


labels = 'MIT', 'Apache 2.0:', 'BSD', 'Creative Commmons', 'Unidentified'
sizes = list(map(lambda x: len(x) / licenseMentions * 100, licenses.values()))
sizes = sizes + [100 - sum(sizes)]
explode = (0, 0, 0, 0, 0)  # explode a slice if required

ax.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%')
ax.axis('equal')

centreCircle1 = plt.Circle((0,0), 0.75, color='white', fc='white', linewidth=1.25)
ax.add_patch(centreCircle1)
ax.set_title('Percentage of licenses (among READMEs that mention licenses)')

plt.show()

# %% [markdown]
# ### - Do maintainers have more then one popular repository? ✅

# %%
# %%opts Bars [width=700, height=700, tools=['hover'] invert_axes=True] (color='#23305E')
#
#
# confirmedFrameworks = open('data/confirmedFrameworks.txt', encoding = 'utf-8').read().splitlines()
# getOwnerFromURL = lambda x: re.search('(?<=\/)[\w|\-]+(?=\/)', x).group(0)
# owners = list(map(getOwnerFromURL, confirmedFrameworks))
#
# ownersValueCounts = pd.Series(owners).value_counts()
# ownersValueCounts = ownersValueCounts.rename_axis('Repo owner').to_frame('Occurence')
#
# bar = hv.Bars(ownersValueCounts)
# bar
# Out:
# :Bars   [Repo owner]   (Occurence)

# %%
print(f"There are {len(ownersValueCounts)} unique repo owners from the top {len(parsedPages)} repos")
# Out:
# There are 67 unique repo owners from the top 85 repos

# %% [markdown]
# ## Status
# ### - Is the building status present? ⍻
#     - Is it passing?

# %%
aTags = map(lambda x: x.find_all('a', href=True), parsedPages)
pageHrefs = map(lambda tagsList: list(map(lambda x: x.attrs['href'], tagsList)), aTags)

travisRegex = re.compile(r'.*travis.*')
getTravisURL = lambda urlList: list(filter(travisRegex.match, urlList))

travisURLs = filter(None, map(getTravisURLs, pageHrefs))
travisURLs = list(map(lambda x: x[0], travisURLs))

travisUsage = len(travisURLs) / len(parsedPages) * 100
print("%.2f%% of the repositories present a travis build status" % travisUsage)  #"%.2f" % a
# Out:
# 49.41% of the repositories present a travis build status

# %%
svgRegex = re.compile(r'.*.svg.*')
addSVGtoURL = lambda url: url if svgRegex.match(url) else url + '.svg'
svgURLs = list(map(addSVGtoURL, travisURLs))

list(map(showSVG, svgURLs))
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]
