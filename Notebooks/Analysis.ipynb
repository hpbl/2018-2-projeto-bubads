# %% [markdown]
#  # Analysis
#
# On this notebook we'll provide implementations to the selected analysis from the [Research Guide](Research%20Guide.ipynb) notebook.

# %%
from bs4 import BeautifulSoup
import re
import os
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud

import holoviews as hv
hv.extension('bokeh')
# Out:
# <link rel="stylesheet" href="https://code.jquery.com/ui/1.10.4/themes/smoothness/jquery-ui.css">
# <style>div.bk-hbox {
#     display: flex;
#     justify-content: center;
# }
#
# div.bk-hbox div.bk-plot {
#     padding: 8px;
# }
#
# div.bk-hbox div.bk-data-table {
#     padding: 20px;
# }
#
# div.hololayout {
#   display: flex;
#   align-items: center;
#   margin: 0;
# }
#
# div.holoframe {
#   width: 75%;
# }
#
# div.holowell {
#   display: flex;
#   align-items: center;
# }
#
# form.holoform {
#   background-color: #fafafa;
#   border-radius: 5px;
#   overflow: hidden;
#   padding-left: 0.8em;
#   padding-right: 0.8em;
#   padding-top: 0.4em;
#   padding-bottom: 0.4em;
#   box-shadow: inset 0 1px 1px rgba(0, 0, 0, 0.05);
#   margin-bottom: 20px;
#   border: 1px solid #e3e3e3;
# }
#
# div.holowidgets {
#   padding-right: 0;
#   width: 25%;
# }
#
# div.holoslider {
#   min-height: 0 !important;
#   height: 0.8em;
#   width: 100%;
# }
#
# div.holoformgroup {
#   padding-top: 0.5em;
# ...

# %%
def parsePage(htmlFilePath):
    return BeautifulSoup(open(htmlFilePath).read(), "html.parser")

def parseAllPages(directoryPath):
    filesPaths = [directoryPath + f for f in os.listdir(directoryPath) if not f.startswith('.')]
    return list(map(parsePage, filesPaths))

# parsed_page.find_all(headersRegex)
basePath = 'data/READMES/HTML/'

parsedPages = parseAllPages(basePath)

# %% [markdown]
# ## README file structure
#
# ### 27. What are the most common section titles?

# %%
headersRegex = re.compile('^h[1-6]$')
getHeaders = lambda parsedPage: parsedPage.find_all(headersRegex)
flatten = lambda l: [item.text for sublist in l for item in sublist]

headers = flatten(map(getHeaders, parsedPages))

# %%
# %%opts Bars [width=900, height=500, tools=['hover'] invert_axes=True] (color='#23305E')
# # bar = hv.Bars(headersValueCountsFiltered, 'Country Name','2010')
# # bar
#
# headersValueCounts = pd.DataFrame(headers)[0].value_counts()
# headersValueCountsFiltered = headersValueCounts[headersValueCounts > 5]
# headersValueCountsFiltered = headersValueCountsFiltered.rename_axis('Header').to_frame('Occurence')
#
# bar = hv.Bars(headersValueCountsFiltered)
# bar
# Out:
# :Bars   [Header]   (Occurence)

# %%
removeSpecialCharacters = lambda x: re.sub('\\xa0', ' ', x)

headerFrequencyDict = headersValueCounts.to_dict() #headersValueCountsFiltered.to_dict()['Occurence']

wordcloud = WordCloud(width=900, height=600, min_font_size=10,  background_color="white").generate_from_frequencies(headerFrequencyDict)
plt.figure(figsize=(9, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %% [markdown]
# <li value = 41> Size of the README files. </li>
# <ul><li>Does the order of the sections follow a common order?</li></ul>
